# %%
from osu_file_parser import create_stats_entry, Beatmap

# %%
fpath = "./Feryquitous feat. Aitsuki Nakuru - Kairikou (cococolaco) [Another].osu"
create_stats_entry(fpath = "./Feryquitous feat. Aitsuki Nakuru - Kairikou (cococolaco) [Another].osu", lazer=True)
# Out:
# {'avg_num_jumps': 10.0,
#  'avg_stream_length': 0,
#  'avg_burst_length': 3.048780487804878,
#  'avg_irr_length': 2.0,
#  'overall_irr_percent': 8.206330597889801,
#  'num_jump_secs': 65,
#  'num_stream_secs': 0,
#  'num_burst_secs': 41,
#  'num_irr_secs': 35,
#  'is_regular': False,
#  'is_jump': False,
#  'stream-density': 0.15357561547479484,
#  'stream-spacing': 0.0,
#  'ar': 9.2,
#  'bpm': 206,
#  'id': 1744644,
#  'beatmapset_id': 1744644,
#  'title': 'Kairikou',
#  'artist': 'Feryquitous feat. Aitsuki Nakuru',
#  'creator': 'cococolaco',
#  'star_rating': 5.610452987018,
#  'pp_100': 254.5652219688712,
#  'pp_95': 165.66716078465646,
#  'tags': 'フェリキタス soleil de minuit loli catgirl loli_catgirl',
#  'max_combo': 1291,
#  'bg_url': 'https://assets.ppy.sh/beatmaps/832836/covers/cover.jpg',
#  'url': 'https://osu.ppy.sh/beatmapsets/832836#osu/1744644',
#  'version': 'Another',
#  '_fpath': '.\\Feryquitous feat. Aitsuki Nakuru - Kairikou (cococolaco) [Another].osu'}
